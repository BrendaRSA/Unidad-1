# %% [markdown]
# # Examen Unidad 1

# %%
import pandas as pd
import numpy as np

# %%
sales = pd.read_csv("VGSales.csv")

# %%
sales.head()
# Out:
#    Rank           Nombre Plataforma    Year     Genre   Publisher  NA_Sales  \
# 0    90          Pac-Man       2600  1982.0    Puzzle       Atari      7.28
# 1   240         Pitfall!       2600  1981.0  Platform  Activision      4.21
# 2   259        Asteroids       2600  1980.0   Shooter       Atari      4.00
# 3   545  Missile Command       2600  1980.0   Shooter       Atari      2.56
# 4   608   Space Invaders       2600     NaN   Shooter       Atari      2.36
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      0.45       0.0         0.08          7.81
# 1      0.24       0.0         0.05          4.50
# 2      0.26       0.0         0.05          4.31
# 3      0.17       0.0         0.03          2.76
# 4      0.14       0.0         0.03          2.53

# %%
rank = sales[sales(["Rank"] )
rank
# Out:
#   Input In [18]
#     rank
#     ^
# SyntaxError: invalid syntax

# %%
juegos = sales [(( sales["Publisher"] == "Atari") & ( sales ["Genre"] == "Action"))]
juegos.head()
# Out:
#     Rank                       Nombre Plataforma    Year   Genre Publisher  \
# 7    866  E.T.: The Extra Terrestrial       2600  1981.0  Action     Atari
# 17  1587                       Combat       2600     NaN  Action     Atari
# 37  2674              Crystal Castles       2600  1983.0  Action     Atari
# 55  3955               Midnight Magic       2600  1983.0  Action     Atari
# 58  4017      Raiders of the Lost Ark       2600  1981.0  Action     Atari
#
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 7       1.84      0.11       0.0         0.02          1.97
# 17      1.17      0.07       0.0         0.01          1.25
# 37      0.72      0.04       0.0         0.01          0.77
# 55      0.47      0.03       0.0         0.01          0.50
# 58      0.46      0.03       0.0         0.01          0.50

# %%
año = [(sales["Year"] == "1987.0") (sales["Plataforma"] == "NES")]
año
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
juegos = [((sales["Plataforma"] == "PS4") | (sales["Plataforma"] == "Wii") | (sales["Plataforma"] == "X360") 
          
          & (sales["Genre"] == "Action") | (sales["Genre"] == "Fighting") | (sales["Genre"] == "Puzle")]
juegos
# Out:
#   Input In [51]
#     & (sales["Genre"] == "Action") | (sales["Genre"] == "Fighting") | (sales["Genre"] == "Puzle")]
#                                                                                                  ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '(' on line 1

# %%
sales.tail()
# Out:
#         Rank                    Nombre Plataforma    Year     Genre  \
# 16593  16533  Sébastien Loeb Rally Evo       XOne  2016.0    Racing
# 16594  16534             Hitman (2016)       XOne  2016.0    Action
# 16595  16565              Mighty No. 9       XOne  2016.0  Platform
# 16596  16572        Resident Evil 4 HD       XOne  2016.0   Shooter
# 16597  16579         Rugby Challenge 3       XOne  2016.0    Sports
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 16593       Milestone S.r.l      0.00      0.01       0.0          0.0
# 16594           Square Enix      0.00      0.01       0.0          0.0
# 16595           Deep Silver      0.01      0.00       0.0          0.0
# 16596                Capcom      0.01      0.00       0.0          0.0
# 16597  Alternative Software      0.00      0.01       0.0          0.0
#
#        Global_Sales
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01

# %%
superm = pd.read_csv("supermarket_sales.csv")

# %%
superm.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender       Product line  \
# 0  253-12-6086      A     Yangon        Member  Female  Sports and travel
# 1  276-54-0879      B   Mandalay        Normal    Male  Sports and travel
# 2  373-14-0504      A     Yangon        Member  Female  Sports and travel
# 3  659-36-1684      C  Naypyitaw        Member    Male  Sports and travel
# 4  751-15-6198      B   Mandalay        Normal    Male  Sports and travel
#
#    Unit price  Quantity  Tax 5%    Total  Rating      Payment        Date  \
# 0       98.40         7  34.440  $723.24     8.7  Credit card  03/12/2019
# 1       97.74         4  19.548  $410.51     6.4      Ewallet  03/12/2019
# 2       71.63         2   7.163  $150.42     8.8      Ewallet  02/12/2019
# 3       57.12         7  19.992  $419.83     6.5  Credit card  01/12/2019
# 4       23.01         6   6.903  $144.96     7.9      Ewallet  01/12/2019
#
#              Time    cogs  gross margin percentage  gross income
# ...

# %%
superm = [(superm ["City"] == "Yangon") & (superm["Gender"]=="Male") & 
          (superm ["Product line"]== "Sports and travel")
         & (superm ["Payment"]== "Credit card")]
superm
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  1005    False
#  1006    False
#  1007    False
#  1008    False
#  1009    False
#  Length: 1010, dtype: bool]

# %%
superm = [(superm ["City"] == "Yangon") & (superm["Payment"]=="")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [74], in <cell line: 1>()
# ----> 1 superm = [(superm ["City"] == "Yangon")]
#
# TypeError: list indices must be integers or slices, not str
